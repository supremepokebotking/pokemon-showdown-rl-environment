# %%
import model as model_env
import agent
import architecture as policies
import poke_environ as env

import tensorflow as tf
import numpy as np
import gym
import math
import os

import architecture as policies
import poke_environ as env

# SubprocVecEnv creates a vector of n environments to run them simultaneously.
from baselines.common.vec_env.subproc_vec_env import SubprocVecEnv
from baselines.common.vec_env.dummy_vec_env import DummyVecEnv
from tensorflow.keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def get_model(policy, env, nsteps, total_timesteps, gamma, lam, vf_coef, ent_coef, lr, cliprange, max_grad_norm, log_interval):
	noptepochs = 4
	nminibatches = 8

	if isinstance(lr, float): lr = constfn(lr)
	else: assert callable(lr)
	if isinstance(cliprange, float): cliprange = constfn(cliprange)
	else: assert callable(cliprange)

	# Get the nb of env
	nenvs = env.num_envs

	# Get state_space and action_space
	ob_space = env.observation_space
	ac_space = env.action_space

	#Calculate the batch size
	batch_size = nenvs * nsteps # For instance if we take 5 steps and we have 5 environments batch_size = 25

	batch_train_size = batch_size // nminibatches

	assert batch_size % nminibatches == 0

	#Instantiate the model object (that creates step_model and train_model)
	model = model_env.Model(policy=policy, ob_space=ob_space, action_space=ac_space,nenvs=nenvs, nsteps=nsteps,
		ent_coef=ent_coef,vf_coef=vf_coef,max_grad_norm=max_grad_norm)
	return model

# %%
load_path = './models/3090/model.ckpt'
config = tf.ConfigProto()

# Avoid warning message errors
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# Allowing GPU memory growth
config.gpu_options.allow_growth = True
K.clear_session()
with tf.Session(config=config):

    model = get_model(policy=policies.PPOPolicy,
                                env=SubprocVecEnv([
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                    ]),
                                nsteps=32, # Steps per environment
    #							nsteps=2048, # Steps per environment
    #							total_timesteps=10000000,
                                total_timesteps=10000000,
                                gamma=0.99,
                                lam=0.95,
                                vf_coef=0.5,
                                ent_coef=0.01,
                                lr = lambda _:2e-4,
                                cliprange = lambda _:0.2, # 0.1 * learning_rate
                                max_grad_norm = 0.5,
                                log_interval  = 10)
    model.load(load_path)
    
    print(model_env.deep_testing(model))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9a529af2db92> in <module>
#       1 load_path = './models/3090/model.ckpt'
# ----> 2 config = tf.ConfigProto()
#       3
#       4 # Avoid warning message errors
#       5 os.environ['CUDA_VISIBLE_DEVICES'] = '0'
#
# NameError: name 'tf' is not defined

# %%
load_path = './models/360/model.ckpt'
config = tf.ConfigProto()

# Avoid warning message errors
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# Allowing GPU memory growth
config.gpu_options.allow_growth = True
K.clear_session()
mean = 0
results = {}
steps = []
with tf.Session(config=config):

    model = get_model(policy=policies.PPOPolicy,
                                env=SubprocVecEnv([
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                    ]),
                                nsteps=32, # Steps per environment
    #							nsteps=2048, # Steps per environment
    #							total_timesteps=10000000,
                                total_timesteps=10000000,
                                gamma=0.99,
                                lam=0.95,
                                vf_coef=0.5,
                                ent_coef=0.01,
                                lr = lambda _:2e-4,
                                cliprange = lambda _:0.2, # 0.1 * learning_rate
                                max_grad_norm = 0.5,
                                log_interval  = 10)
    model.load(load_path)
    
    mean, results, steps = model_env.deep_testing(model)
    print(mean, results, steps)
# Out:
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/model.py:56: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/model.py:61: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/architecture.py:86: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# em shape (?, 200)
# WARNING:tensorflow:From /home/ml_sprint/anaconda3/envs/pytorch-py3p6-env/lib/python3.6/site-packages/tensorflow/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# emb shape (?, 200, 20)
# WARNING:tensorflow:From /home/ml_sprint/anaconda3/envs/pytorch-py3p6-env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/ml_sprint/anaconda3/envs/pytorch-py3p6-env/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:3794: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# text_flatten before reshape (?, 200, 100)
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/baselines-master/baselines/a2c/utils.py:61: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/architecture.py:28: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/architecture.py:172: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/architecture.py:176: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/architecture.py:177: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# this did finish
# em shape (?, 200)
# emb shape (?, 200, 20)
# text_flatten before reshape (?, 200, 100)
# this did finish
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/model.py:147: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/ml_sprint/anaconda3/envs/pytorch-py3p6-env/lib/python3.6/site-packages/tensorflow/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/ml_sprint/Desktop/poke_test_env/model.py:211: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Loading ./models/360/model.ckpt
# WARNING:tensorflow:From /home/ml_sprint/anaconda3/envs/pytorch-py3p6-env/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./models/360/model.ckpt
# /home/ml_sprint/anaconda3/envs/pytorch-py3p6-env/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_3
# trail: 100
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_4
# trail: 200
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_2
# trail: 300
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Struggle but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# trail: 400
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_3 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_6
# trail: 500
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# trail: 600
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_4 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# trail: 700
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_2
# trail: 800
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Struggle but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Attack_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Attack_Slot_2
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_4 but got Actions.Change_Pokemon_Slot_4
# trail: 900
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Attack_Slot_4
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_UltraBurst_Slot_1 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_UltraBurst_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_6
# Bot chose Actions.Attack_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_2 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_4 but got Actions.Attack_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_3
# Bot chose Actions.Attack_Z_Slot_1 but got Actions.Change_Pokemon_Slot_2
# Bot chose Actions.Attack_Struggle but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_Slot_3 but got Actions.Change_Pokemon_Slot_5
# Bot chose Actions.Attack_Z_Slot_3 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_1
# Bot chose Actions.Attack_UltraBurst_Slot_2 but got Actions.Change_Pokemon_Slot_4
# Bot chose Actions.Attack_Slot_4 but got Actions.Change_Pokemon_Slot_5
# trail: 1000
# 0.16426000197604299 {'player': 503, 'agent': 497} [40, 61, 66, 59, 40, 60, 91, 35, 98, 45, 38, 44, 61, 71, 51, 92, 53, 80, 69, 87, 51, 85, 37, 44, 51, 51, 99, 72, 45, 46, 53, 68, 107, 83, 70, 44, 80, 64, 85, 61, 36, 73, 39, 52, 34, 55, 110, 59, 41, 47, 82, 77, 40, 74, 49, 79, 53, 59, 34, 51, 50, 87, 53, 117, 55, 85, 75, 52, 64, 39, 59, 59, 83, 59, 42, 54, 37, 77, 107, 101, 55, 26, 51, 56, 80, 37, 42, 62, 56, 49, 54, 35, 63, 38, 52, 52, 54, 49, 93, 53, 48, 39, 76, 36, 94, 42, 82, 59, 58, 54, 102, 56, 66, 67, 31, 55, 72, 82, 59, 45, 70, 42, 63, 48, 60, 52, 32, 66, 98, 78, 46, 85, 38, 41, 60, 92, 64, 59, 54, 65, 83, 50, 68, 108, 58, 38, 55, 36, 56, 82, 52, 79, 37, 45, 88, 73, 39, 39, 71, 73, 102, 44, 59, 39, 55, 67, 60, 71, 141, 63, 54, 52, 90, 63, 73, 80, 39, 88, 40, 48, 53, 59, 60, 81, 71, 74, 70, 44, 75, 32, 47, 60, 83, 42, 65, 63, 55, 30, 34, 48, 59, 52, 128, 44, 37, 94, 44, 81, 76, 70, 118, 45, 77, 64, 74, 30, 45, 83, 65, 76, 86, 103, 57, 60, 33, 75, 73, 50, 63, 38, 49, 42, 54, 78, 37, 38, 62, 36, 51, 40, 45, 63, 56, 88, 68, 43, 36, 46, 37, 44, 86, 150, 88, 40, 58, 64, 73, 53, 41, 41, 54, 40, 64, 34, 61, 67, 55, 61, 70, 56, 33, 87, 88, 44, 54, 85, 30, 60, 49, 72, 59, 64, 38, 35, 56, 46, 62, 91, 39, 84, 53, 74, 52, 49, 71, 49, 37, 42, 40, 37, 68, 44, 47, 59, 43, 47, 68, 54, 71, 61, 26, 124, 75, 92, 81, 72, 68, 41, 63, 105, 150, 36, 74, 85, 46, 41, 42, 43, 72, 72, 76, 95, 86, 92, 30, 53, 81, 57, 42, 75, 93, 80, 52, 118, 54, 78, 37, 57, 60, 49, 66, 59, 103, 74, 71, 65, 52, 45, 50, 34, 69, 39, 46, 64, 60, 92, 63, 37, 45, 38, 52, 39, 67, 43, 53, 47, 57, 52, 86, 33, 52, 66, 52, 52, 57, 78, 45, 61, 62, 76, 47, 79, 41, 64, 93, 93, 56, 68, 33, 65, 97, 55, 57, 108, 75, 34, 52, 50, 68, 66, 64, 73, 59, 92, 55, 44, 62, 62, 45, 70, 72, 67, 119, 42, 39, 87, 87, 53, 33, 68, 73, 53, 67, 74, 122, 61, 50, 58, 91, 45, 67, 76, 74, 80, 53, 83, 59, 58, 52, 56, 29, 63, 72, 37, 72, 92, 91, 53, 47, 87, 65, 94, 46, 70, 48, 76, 76, 49, 41, 55, 29, 44, 42, 55, 50, 54, 64, 60, 42, 50, 94, 72, 77, 41, 48, 47, 90, 56, 43, 94, 67, 61, 55, 48, 47, 49, 65, 79, 64, 79, 73, 53, 71, 93, 79, 54, 43, 72, 70, 36, 72, 67, 42, 33, 71, 48, 38, 63, 51, 33, 62, 34, 35, 39, 56, 47, 37, 74, 55, 41, 100, 84, 45, 76, 73, 47, 42, 46, 33, 45, 36, 51, 66, 51, 37, 57, 83, 61, 36, 35, 41, 47, 62, 27, 75, 62, 48, 75, 34, 71, 69, 130, 31, 80, 42, 59, 67, 57, 49, 36, 47, 56, 36, 52, 112, 80, 32, 65, 65, 50, 135, 79, 35, 42, 55, 87, 26, 73, 81, 70, 79, 48, 69, 43, 24, 81, 44, 87, 55, 73, 88, 43, 83, 30, 54, 89, 88, 54, 45, 39, 39, 50, 46, 68, 52, 52, 45, 56, 65, 109, 59, 52, 41, 47, 49, 54, 41, 59, 30, 41, 48, 40, 50, 53, 42, 37, 37, 56, 63, 60, 60, 68, 57, 92, 80, 45, 116, 89, 48, 77, 70, 106, 82, 51, 68, 77, 63, 32, 38, 37, 65, 44, 68, 44, 36, 78, 51, 38, 45, 43, 25, 108, 44, 60, 37, 74, 28, 46, 51, 95, 55, 55, 55, 74, 87, 83, 92, 96, 48, 64, 40, 75, 67, 46, 105, 42, 76, 65, 64, 69, 51, 42, 69, 82, 65, 49, 57, 78, 52, 78, 93, 82, 58, 52, 48, 45, 50, 55, 46, 60, 53, 38, 35, 41, 75, 106, 51, 54, 51, 64, 54, 84, 48, 95, 50, 43, 66, 47, 69, 82, 108, 40, 49, 58, 63, 59, 81, 40, 49, 72, 50, 73, 67, 60, 104, 78, 62, 70, 72, 77, 87, 34, 111, 103, 65, 109, 47, 45, 35, 58, 36, 91, 79, 58, 83, 54, 29, 60, 31, 45, 48, 40, 60, 52, 61, 32, 47, 68, 74, 72, 71, 36, 71, 48, 42, 62, 56, 73, 45, 63, 125, 47, 38, 64, 47, 65, 32, 28, 63, 77, 66, 57, 46, 51, 65, 89, 56, 46, 47, 75, 60, 69, 87, 57, 61, 36, 48, 81, 42, 48, 53, 50, 55, 36, 68, 50, 50, 27, 58, 56, 44, 55, 47, 56, 91, 73, 75, 36, 67, 54, 34, 45, 88, 52, 54, 45, 68, 59, 37, 85, 44, 66, 41, 87, 48, 87, 50, 78, 44, 54, 73, 41, 32, 55, 53, 75, 76, 31, 44, 91, 60, 95, 86, 38, 78, 40, 62, 54, 46, 94, 47, 64, 58, 25, 61, 104, 56, 72, 103, 57, 74, 49, 83, 52, 42, 33, 72, 57, 67, 57, 78, 91, 36, 55, 31, 100, 85, 44, 39, 84, 73, 79, 61, 53, 80, 83, 57, 98, 36, 44, 101, 43, 64, 70, 33, 50, 95, 82, 51, 45, 47, 55, 70, 46, 72, 39, 44, 63, 80, 74, 81, 50, 57, 62, 69, 71, 61, 59, 68, 50, 64, 41, 70, 36, 60, 81, 54, 92, 40, 69, 93, 36, 36, 75, 102, 72, 63, ...

# %%
load_path = './models/360/model.ckpt'
config = tf.ConfigProto()

# Avoid warning message errors
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# Allowing GPU memory growth
config.gpu_options.allow_growth = True
K.clear_session()
with tf.Session(config=config):

    model = get_model(policy=policies.PPOPolicy,
                                env=SubprocVecEnv([
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                        env.make_poke_env(),
                                    ]),
                                nsteps=32, # Steps per environment
    #							nsteps=2048, # Steps per environment
    #							total_timesteps=10000000,
                                total_timesteps=10000000,
                                gamma=0.99,
                                lam=0.95,
                                vf_coef=0.5,
                                ent_coef=0.01,
                                lr = lambda _:2e-4,
                                cliprange = lambda _:0.2, # 0.1 * learning_rate
                                max_grad_norm = 0.5,
                                log_interval  = 10)
    model.load(load_path)
    
    print(model_env.testing(model))
# Out:
# em shape (?, 200)
# emb shape (?, 200, 20)
# text_flatten before reshape (?, 200, 100)
# this did finish
# em shape (?, 200)
# emb shape (?, 200, 20)
# text_flatten before reshape (?, 200, 100)
# this did finish
# Loading ./models/360/model.ckpt
# INFO:tensorflow:Restoring parameters from ./models/360/model.ckpt
# /home/ml_sprint/anaconda3/envs/pytorch-py3p6-env/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# 0.8100000179062287
